# %% [markdown]
# <a href="https://colab.research.google.com/github/AidanJIC/Clasificaci-n-de-productos-en-supermercados-utilizando-visi-n-computacional/blob/main/Practica_06_Introducci%C3%B3n_a_OpenCV_Operaciones_de_punto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ESCUELA DE INGENIERÍA MECATRÓNICA**
#
# ## `PROCESAMIENTO DIGITAL DE SEÑALES E IMÁGENES`
#
# ### `Docente: Ms. Ing. Emerson Maximo Asto Rodriguez`
#
# ```
# Práctica 6: OpenCV y Operaciones de punto
# ```

# %% [markdown]
# # <font color=#FF0000>OpenCV</color>
#
# * Mas de 2500 algoritmos optimizados
#
# * C/C++, Python, Java y MATLAB, soporta Windows, Linux, Android y Mac OS
#
# * Cuda y OpenCL (Actualmente en desarrollo)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### **Leer y mostrar una imagen con OpenCV**

# %% [markdown]
# Lectura -> cv2.imread(ruta de imagen, opc*)
#  * Corregir colores usando indexación
#  * Corregir colores cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
#  * opc -> cv2.IMREAD_GRAYSCALE

# %%
imgSRC = '../Imagenes/robotSofia.jfif'

# %%
img = cv2.imread(imgSRC) #[..., ::-1]
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# plt.figure(figsize=(15,10))
plt.imshow(img)
plt.show()

# %% [markdown]
# P1. Que sucede si usamos matplotlib para mostrar una imágen leída con openCV?
#   Si cargas la imagen con matplotlib se va observar una diferencia en los colores de la imagen, esto debido que en matplotlib emplean el modelo RGB (rojo, verde, azul) mientras que openCV trabaja con BGR (azul, verde, rojo).

# %% [markdown]
# ### **Consideraciones al mostrar imagenes con matplotlib**
#  * Se realiza un autoescalado

# %%
img = cv2.imread(imgSRC,0)
plt.figure(figsize=(15,10))
plt.imshow(img, cmap='gray')
plt.show()

# %%
black = np.zeros([100, 100], dtype=np.uint8)
gray = np.ones([100, 100], dtype=np.uint8) * 128
white = np.ones([100, 100], dtype=np.uint8) * 255

plt.subplots(1, 3, figsize=(15,5))
plt.subplot(131)
plt.imshow(black, cmap='gray', vmin=0, vmax=255)
plt.subplot(132)
plt.imshow(gray, cmap='gray', vmin=0, vmax=255)
plt.subplot(133)
plt.imshow(white, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# P2. Explique la utilidad de vmin y vmax y cuando es importante tenerlo en cuenta
#   El parametro vmin y vmax sirve para ajustar el contraste de la imagen de forma que los valores menores de vmin se asignarán al color más oscuro (o mas bajo) y los valores mayores de vmax se asignarán al color más claro (o mas alto).

# %% [markdown]
# ### **Escalando los colores y dibujando dentro de una imagen**

# %%
black = np.zeros([100, 100], dtype=np.uint8)
black[10:90, 30:60] = 128

black = black/255

plt.imshow(black, cmap='gray', vmin=0, vmax=1)
plt.show()

# %% [markdown]
# P3. Que tipo de dato es la imagen despues de dividir entre 255?
#     El tipo de dato es un flotante comprendido entre 0 y 1.
#
#
# P4. Explique como funcionan los ejes en las imágenes mostradas en python.
#     Los ejes en matplotlib representan las dimensiones de la imagen a trabajar y estan ordendados de izquierda a derecha y de arriba hacia abajo comenzando con la esquina superior izquierda de la imagen.

# %% [markdown]
# ### **Creando formas dentro de una imagen con numpy y OpenCV**
#  * cv2.rectangle(img, pt1, pt2, (color RGB), thickness= )
#  * cv2.line(img, pt1, pt2, (color RGB),thickness= )
#
# #### (El cuadrado rojo es realizado con numpy.  El cuadrado verde es realizado con OpenCV)

# %%
black = np.zeros([200, 200, 3], dtype=np.uint8)
COLOR = (0,0,255)
PT1 = (5, 20)
PT2 = (100,120)
cv2.rectangle(black, PT1, PT2, COLOR, thickness=-1)
cv2.line(black, PT1, PT2, (255, 0, 0), thickness=2)

plt.imshow(black[..., ::-1], cmap='gray')
plt.show()

# %% [markdown]
# * cv2.circle(img, (centro), radio, (color), thickness=)
#
# * cv2.putText(img, "Texto", (punto de inicio), fuente, tamaño, (color), thickness=)
#  * fuente -> cv2.FONT_HERSHEY_SIMPLEX

# %%
black = np.zeros([200, 200, 3], dtype=np.uint8)
COLOR = (0,0,255)
PT1 = (0, 20)
PT2 = (100,120)

# cv2.rectangle(black, PT1, PT2, COLOR, thickness=-1)
# cv2.line(black, PT1, PT2, (255, 0, 0), thickness=2)
cv2.circle(black, (100,100), 50, (255,0,0), thickness=2)
cv2.putText(black, "Verde", (20,175), cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), thickness=1)

plt.imshow(black[..., ::-1], cmap='gray')
plt.show()

# %% [markdown]
# ### Cambiar tamaño de una imagen con OpenCV-> [resize](https://pythonexamples.org/python-opencv-cv2-resize-image/)
#
# cv2.resize(img, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_NEAREST)
#
# *******
# * INTER_NEAREST
# * INTER_LINEAR
# * INTER_AREA
# * INTER_CUBIC
# * INTER_LANCZOS4

# %%
img = cv2.imread(imgSRC)[...,::-1]

# img_resize_small = cv2.resize(img, None, fx=1/2, fy=1/3, interpolation=cv2.INTER_LINEAR)
img_resize_small = cv2.resize(img, (100,100), interpolation=cv2.INTER_LANCZOS4)
img_resize_big = cv2.resize(img, None, fx=1.2, fy=1.2, interpolation=cv2.INTER_LINEAR)

print(img.shape)
plt.subplots(1, 3, figsize=(15,5))
plt.subplot(131)
plt.imshow(img)
plt.subplot(132)
plt.imshow(img_resize_small)
plt.subplot(133)
plt.imshow(img_resize_big)
plt.show()
# Out:
# (173, 291, 3)

# %% [markdown]
# P5. Cree un bucle para mostrar la imágen original y el efecto de las 5 diferentes interpolaciones al escalar a la mitad su ancho y largo. Se nota la diferencia?

# %%
img = cv2.imread(imgSRC)[...,::-1]

# Redimensionar la imagen con diferentes métodos de interpolación
img_resize_1 = cv2.resize(img, (100, 100), interpolation=cv2.INTER_NEAREST)
img_resize_2 = cv2.resize(img, (100, 100), interpolation=cv2.INTER_LINEAR)
img_resize_3 = cv2.resize(img, (100, 100), interpolation=cv2.INTER_AREA)
img_resize_4 = cv2.resize(img, (100, 100), interpolation=cv2.INTER_CUBIC)
img_resize_5 = cv2.resize(img, (100, 100), interpolation=cv2.INTER_LANCZOS4)

plt.subplots(1, 6, figsize=(18, 5))
plt.subplot(1, 6, 1)
plt.imshow(img)
plt.subplot(1, 6, 2)
plt.imshow(img_resize_1)
plt.subplot(1, 6, 3)
plt.imshow(img_resize_2)
plt.subplot(1, 6, 4)
plt.imshow(img_resize_3)
plt.subplot(1, 6, 5)
plt.imshow(img_resize_4)
plt.subplot(1, 6, 6)
plt.imshow(img_resize_5)
plt.show()

# %% [markdown]
# ### Mostrar imagen con OpenCV en una ventana
# cv2.imshow(nombre de ventana, imagen)
# * cv2.waitKey(0)
# * cv2.destroyAllWindows()

# %%
img = cv2.imread(imgSRC)
cv2.imshow('Robot Sofia', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-14-38792850972c> in <cell line: 2>()
#       1 img = cv2.imread(imgSRC)
# ----> 2 cv2.imshow('Robot Sofia', img)
#       3 cv2.waitKey(0)
#       4 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# # <font color=#FF0000>Operaciones de punto</color>

# %% [markdown]
# ### Negativo de una imagen
#
# * s = 255- f(r)

# %%
r = cv2.imread(imgSRC)[..., ::-1]/255
s = 1 - r
plt.imshow(s)
plt.show()

# %% [markdown]
# ### Tranformacion Logarítmica
# * s = c.log(1+r)

# %%
img = cv2.imread(imgSRC, 0)

fft_2 = np.fft.fft2(img)
fft_2_abs = np.abs(fft_2)
fft_2_abs = np.fft.fftshift(fft_2_abs)
fft_2_abs_log = np.log(fft_2_abs+1)

plt.figure(figsize=(10,15))
plt.imshow(fft_2_abs_log, cmap='gray')
plt.show()

# %% [markdown]
# P6. Compruebe cuanto son los valores mínimo y máximo de la imagen original y de la imágen que muestra el espectro. Luego describa que efecto tuvo la transformación logarítmica.  La transformación logarítmica ayuda a resaltar las intensidades bajas en el espectro. Esto se debe a que el logaritmo comprime el rango de valores altos y expande el rango de valores bajos, permitiendo una mejor visualización de los componentes de frecuencia baja, que están asociados con áreas de baja intensidad (tonos oscuros) en la imagen original.

# %%
# Comprobar los valores mínimo y máximo de la imagen original
min_val_original = np.min(img)
max_val_original = np.max(img)
print(f"Valores de la imagen original: Mínimo = {min_val_original}, Máximo = {max_val_original}")

# Comprobar los valores mínimo y máximo de la imagen del espectro
min_val_log = np.min(fft_2_abs)
max_val_log = np.max(fft_2_abs)
print(f"Valores del espectro: Mínimo = {min_val_log}, Máximo = {max_val_log}")
# Out:
# Valores de la imagen original: Mínimo = None, Máximo = None
# Valores del espectro: Mínimo = 2.551833542454318, Máximo = 9868093.0

# %% [markdown]
# ### Transformación Gamma
# ###   $s=cr^\gamma $

# %%
r = cv2.imread(imgSRC)[..., ::-1]/255
s = r**2.3
plt.imshow(s)
plt.show()

# %% [markdown]
# ### Transformación arbitraria
# * ####   Especificar una funcion de transformacion
# cv2.LUT(img, lut)

# %%
img.shape
# Out:
# (173, 291)

# %%
funcion_ejemplo = np.arange(256)
funcion_ejemplo[90: 140] = 200

img = cv2.imread(imgSRC,0)
img_out = np.empty_like(img)
for m in range(img.shape[0]):
    for n in range(img.shape[1]):
        img_out[m,n] = funcion_ejemplo[img[m,n]]

plt.plot(funcion_ejemplo)
plt.imshow(img, cmap="gray", vmin=0, vmax=255)

# %%
r = np.zeros(256)

for pix in range(256):
    if pix < 50:
        r[pix] = 30/50*(pix-50) + 30
    if 50 <=pix < 100:
        r[pix] = 190/50*(pix-50) + 30
    if 100 <=pix:
        r[pix] = 35/155*(pix-100) + 220

plt.plot(r)
plt.show()

# %%
img = cv2.imread(imgSRC,0)
s=cv2.LUT(img, funcion_ejemplo)
plt.figure(figsize=(8,10))
plt.imshow(s, cmap='gray')
plt.show()

# %% [markdown]
# ### División en capas de bits
#
# * np.bitwise_and(imagen, bit)

# %%
img = cv2.imread(imgSRC, 0)

img7 = cv2.bitwise_and(img, 128)
img6 = cv2.bitwise_and(img, 64)
img5 = cv2.bitwise_and(img, 32)
img4 = cv2.bitwise_and(img, 16)
img3 = cv2.bitwise_and(img, 8)
img2 = cv2.bitwise_and(img, 4)
img1 = cv2.bitwise_and(img, 2)
img0 = cv2.bitwise_and(img, 1)

plt.figure(figsize=(15, 10))
plt.subplot(331)
plt.imshow(img, cmap="gray", vmin=0, vmax=255)
plt.subplot(332)
plt.imshow(img0, cmap="gray")
plt.subplot(333)
plt.imshow(img1, cmap="gray")
plt.subplot(334)
plt.imshow(img2, cmap="gray")
plt.subplot(335)
plt.imshow(img3, cmap="gray")
plt.subplot(336)
plt.imshow(img4, cmap="gray")
plt.subplot(337)
plt.imshow(img5, cmap="gray")
plt.subplot(338)
plt.imshow(img6, cmap="gray")
plt.subplot(339)
plt.imshow(img7, cmap="gray")

# %% [markdown]
# #### Mostrar solo las 5 capas mas significativas

# %%
img_comprimida = img7+ img6 + img5 + img4 + img3 + img2
plt.imshow(img_comprimida, cmap="gray", vmin=0, vmax=255)

# %% [markdown]
# P7. Si usted quisiera encriptar un  mensaje dentro de una fotografía, como lo haría? Para ocultar un mensaje en una fotografía de debe conviertir el mensaje a formato binario y se inserta en los colores de la imagen. Al guardar la imagen, el mensaje queda oculto y la foto se ve igual. Para extraer el mensaje, solo necesitas revisar esos bits modificados y reconstruir el mensaje original.

# %% [markdown]
# ### Histograma de una imagen
# * np.histogram(img, bins, [rango de datos])  (requiere plotear)
# * plt.hist(img.ravel(), bins, [rango de datos])
# * cv2.calcHist([img], [canal], mascara,[bins], [rango de datos])
#
# #####  Normalizar CDF $ \frac{cdf*hist.max}{cdf.max} $

# %%
#Numpy
img = cv2.imread("../Imagenes/rayx.jpg")[..., ::-1]
img_gray = img[..., 0]

hist, bins = np.histogram(img_gray, 256, [0, 256])
plt.bar(np.arange(256), hist)
plt.show()

# %%
#matplotlib
hist = plt.hist(img_gray.ravel(), 256, [0,256], density=True)
cdf = np.cumsum(hist[0])
cdf_norm = cdf*(hist[0].max())/(cdf.max())
plt.plot(cdf_norm)

# %%
# openCV
color = ("r*-", "gs-", "b^-")
for i, col in enumerate(color):
    hist = cv2.calcHist([img], [i], None,[256], [0,256])
    plt.plot(hist, col)

# %% [markdown]
# ### Equalización de Histograma
# * cv2.equalizeHist(img)

# %%
#Numpy
img = cv2.imread("../Imagenes/rayx.jpg")[..., ::-1]
img_gray = img[..., 0]

img_equ = cv2.equalizeHist(img_gray)
plt.imshow(img_equ, cmap="gray", vmin=0, vmax=255)

# %% [markdown]
# P8. Que sucede durante la equalización de histograma? La ecualización del histograma es un proceso que mejora el contraste de una imagen al redistribuir sus niveles de brillo. Al hacerlo, se amplía la gama de intensidades, lo que permite que las áreas oscuras se vuelvan más brillantes y las áreas brillantes se destaquen más, mejorando así la visibilidad de detalles en la imagen.

# %% [markdown]
# ### Equalización de Histograma adaptativa
# *clahe = createCLAHE()
# *clahe.apply(img)
#
# * [CLAHE Histogram Eqalization](https://www.geeksforgeeks.org/clahe-histogram-eqalization-opencv/)

# %%
#Numpy
img = cv2.imread("../Imagenes/rayx.jpg")[..., ::-1]
img_gray = img[..., 0]

clahe = cv2.createCLAHE(clipLimit=5)
final_img = clahe.apply(img_gray) + 60

plt.imshow(final_img, cmap="gray", vmin=0, vmax=255)

# %% [markdown]
# ## Histogram Matching
# https://www.pyimagesearch.com/2021/02/08/histogram-matching-with-opencv-scikit-image-and-python/
# https://automaticaddison.com/how-to-do-histogram-matching-using-opencv/
